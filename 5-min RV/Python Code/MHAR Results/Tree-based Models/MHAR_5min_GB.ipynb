# %% [markdown]
# # Gradient Boosting (GB) on the MHAR 5-min Feature Set

# %% [markdown]
# **Purpose:** The purpose of this notebook is to compute the out-of-sample forecast performance of the Gradient Boosting (GB) model on the $\mathcal{M}_{\mathrm{HAR}}$ 5-min feature set for the EURO STOXX 50 index over the period 1999--2020, following the methodology of Christensen et al. (2023).
#
# The Gradient Boosting model builds on regression trees by combining a sequence of weak learners, where each new tree is fitted to improve upon the errors made by the previous ones. In contrast to Random Forest, which averages many independently grown trees, Gradient Boosting constructs trees sequentially and is therefore better suited to reducing underfitting and capturing more complex nonlinear relationships.
#
# The baseline forecasting relation is written as:
#
# $$
# RV_{t+1} = f(Z_t) + \varepsilon_{t+1},
# $$
#
# where \(Z_t\) denotes the vector of predictors and, in the present specification, consists of:
#
# - $RV_t$ (RVD) — daily realized variance
# - $\overline{RV}_t^{(w)} = \frac{1}{5}\sum_{i=0}^{4} RV_{t-i}$ (RVW) — 5-day rolling average of realized variance
# - $\overline{RV}_t^{(m)} = \frac{1}{22}\sum_{i=0}^{21} RV_{t-i}$ (RVM) — 22-day rolling average of realized variance
#
# In the Gradient Boosting model, the prediction function is updated iteratively as:
#
# $$
# \hat{f}_b(Z_t)
# =
# \hat{f}_{b-1}(Z_t)
# +
# \eta \sum_{j=1}^{J_b} q_{jb}\mathbf{1}\{Z_t \in R_{jb}\},
# \qquad b = 1, \dots, B,
# $$
#
# where \(\hat{f}_{b-1}(Z_t)\) is the prediction from the previous boosting iteration, \(\eta\) is the learning rate, \(R_{jb}\) denotes the \(j\)-th terminal node of tree \(b\), and \(q_{jb}\) is the corresponding node-specific update. The final forecast is given by
# \(\hat{f}(Z_t) = \hat{f}_B(Z_t)\).
#
# The model is estimated using a rolling forecasting scheme with a fixed train/validation/test split (70/10/20). In line with Christensen et al. (2023), the GB model is implemented as a tree-based learner designed to capture nonlinearities and interactions in the realized variance predictors, with one-day-ahead forecasts generated throughout the test period to evaluate out-of-sample predictive accuracy.

# %% [markdown]
# ## 1. Loading Data
# Loading in data from the MALL_5min.csv file

# %%
import pandas as pd
import numpy as np
import os
import time
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor

# Load MALL dataset
file_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/5-min RV/Cleaned Data Sets/MALL_5min.csv"
MALL = pd.read_csv(file_path, index_col='Date', parse_dates=True)

print(f"Shape: {MALL.shape}")
print(f"Date range: {MALL.index[0].date()} to {MALL.index[-1].date()}")
print(f"NaN values: {MALL.isna().sum().sum()}")
MALL.head()
# Out:
# Shape: (5489, 31)
# Date range: 1999-01-05 to 2020-08-06
# NaN values: 0
#                  RVD       RVW       RVM    logRVD    logRVW    logRVM  \
# Date
# 1999-01-05  0.000106  0.000089  0.000141 -9.153100 -9.328531 -8.866447
# 1999-01-06  0.000047  0.000090  0.000132 -9.966398 -9.316927 -8.935760
# 1999-01-07  0.000237  0.000123  0.000131 -8.347779 -9.004761 -8.938374
# 1999-01-08  0.000168  0.000146  0.000114 -8.689606 -8.832472 -9.082830
# 1999-01-11  0.000282  0.000168  0.000117 -8.175339 -8.692020 -9.056351
#
#              RVD_pos   RVD_neg    RD_neg    RW_neg  ...  BRENT  BRENT_ret  \
# Date                                                ...
# 1999-01-05  0.000071  0.000035  0.000000 -0.000960  ...  10.30  -0.060282
# 1999-01-06  0.000038  0.000009  0.000000 -0.000960  ...  10.67   0.035292
# 1999-01-07  0.000110  0.000127 -0.012859 -0.003532  ...  11.08   0.037706
# 1999-01-08  0.000079  0.000089 -0.005883 -0.003748  ...  11.70   0.054447
# ...

# %% [markdown]
# ## 2. Data Split
# ### 2.1 Train / Validation / Test Split (70 / 10 / 20)

# %% [markdown]
# Following Christensen et al. (2023), we split the sample into a training set (70%),
# validation set (10%), and test set (20%). The test set is reserved exclusively for
# out-of-sample evaluation and no estimation or tuning is conducted on it.

# %%
# Train / Validation / Test split (70 / 10 / 20)
n = len(MALL)
n_train = int(0.70 * n)
n_val = int(0.10 * n)
n_test = n - n_train - n_val

print(f"Training observations:   {n_train}")
print(f"Validation observations: {n_val}")
print(f"Test observations:       {n_test}")

print(f"Training period:   {MALL.index[0].date()} to {MALL.index[n_train - 1].date()}")
print(f"Validation period: {MALL.index[n_train].date()} to {MALL.index[n_train + n_val - 1].date()}")
print(f"Test period:       {MALL.index[n_train + n_val].date()} to {MALL.index[-1].date()}")
# Out:
# Training observations:   3842
# Validation observations: 548
# Test observations:       1099
# Training period:   1999-01-05 to 2014-02-26
# Validation period: 2014-02-27 to 2016-04-20
# Test period:       2016-04-21 to 2020-08-06

# %% [markdown]
# ## 3. Gradient Boosting
# ### 3.1 Model Specification

# %% [markdown]
# The Gradient Boosting (GB) model builds on the baseline HAR specification by replacing the linear forecasting equation with an additive ensemble of regression trees that are estimated sequentially. In contrast to Random Forest, which averages independently grown trees, Gradient Boosting constructs trees iteratively, where each new tree is fitted to improve upon the errors of the current model.
#
# The model is defined as:
#
# $$
# RV_{t+1} = f(Z_t) + \varepsilon_{t+1}
# $$
#
# where \(Z_t\) denotes the vector of predictors and, in the present specification, consists of:
#
# - $RV_t$ (RVD) — daily realized variance
# - $\overline{RV}_t^{(w)} = \frac{1}{5}\sum_{i=0}^{4} RV_{t-i}$ (RVW) — 5-day rolling average of realized variance
# - $\overline{RV}_t^{(m)} = \frac{1}{22}\sum_{i=0}^{21} RV_{t-i}$ (RVM) — 22-day rolling average of realized variance
#
# The Gradient Boosting predictor is constructed as a sum of \(B\) regression trees:
#
# $$
# \hat{f}(Z_t) = \sum_{b=1}^{B} \nu \cdot \hat{f}_b(Z_t),
# $$
#
# where \(B\) denotes the number of boosting iterations (trees), \(\nu \in (0,1]\) is the learning rate controlling the contribution of each tree, and \(\hat{f}_b(Z_t)\) represents the prediction from tree \(b\).
#
# Each tree is estimated sequentially by fitting it to the residuals of the current model, thereby gradually improving the fit. This sequential updating allows the model to capture complex nonlinearities and interactions in the predictors. However, it also makes the model more sensitive to hyperparameter choices compared to Random Forest, requiring careful control of parameters such as the learning rate, tree depth, and number of boosting iterations to avoid overfitting.

# %% [markdown]
# ### 3.2 Feature Set Construction
# Extracting the dependent and independent variables relevant for the GB model

# %%
# Define target and MHAR feature set
y = MALL["RV_target"].values
X_MHAR = MALL[["RVD", "RVW", "RVM"]].values

# Split into train, validation and test sets
X_train = X_MHAR[:n_train]
X_val = X_MHAR[n_train:n_train + n_val]
X_test = X_MHAR[n_train + n_val:]

y_train = y[:n_train]
y_val = y[n_train:n_train + n_val]
y_test = y[n_train + n_val:]

# Standardize using training-sample moments, following the paper
X_mean = X_train.mean(axis=0)
X_std = X_train.std(axis=0, ddof=0)
X_std = np.where(X_std == 0, 1.0, X_std)

X_scaled = (X_MHAR - X_mean) / X_std
X_train_scaled = X_scaled[:n_train]
X_val_scaled = X_scaled[n_train:n_train + n_val]
X_test_scaled = X_scaled[n_train + n_val:]

print("Feature set: RVD, RVW, RVM")
print(f"\nFull dataset:   X={X_scaled.shape}, y={y.shape}")
print(f"Training set:   X={X_train_scaled.shape}, y={y_train.shape}")
print(f"Validation set: X={X_val_scaled.shape}, y={y_val.shape}")
print(f"Test set:       X={X_test_scaled.shape}, y={y_test.shape}")
print("\nStandardization check on training sample:")
print(f"  Means: {X_train_scaled.mean(axis=0).round(6)}")
print(f"  Std:   {X_train_scaled.std(axis=0).round(6)}")
# Out:
# Feature set: RVD, RVW, RVM
#
# Full dataset:   X=(5489, 3), y=(5489,)
# Training set:   X=(3842, 3), y=(3842,)
# Validation set: X=(548, 3), y=(548,)
# Test set:       X=(1099, 3), y=(1099,)
#
# Standardization check on training sample:
#   Means: [ 0. -0. -0.]
#   Std:   [1. 1. 1.]

# %% [markdown]
# ## 5. Gradient Boosting Model Specification and Hyperparameter Tuning
#
# Appendix A.4 of the paper tunes three GB hyperparameters in the validation set: tree depth in `{1, 2}`, number of trees in `{50, 100, ..., 500}`, and learning rate in `{0.01, 0.1}`. To make a full run feasible today, exploratory mode uses a reduced grid and then fixes the best-performing parameter combination from the initial validation exercise for the rolling forecast stage. Setting `exploratory_mode = False` restores the paper-faithful rolling re-tuning setup.

# %%
# Gradient Boosting hyperparameter grid
depth_grid = [1, 2]
n_estimators_grid = [50, 100, 150, 200, 250, 300]
learning_rate_grid = [0.01, 0.1]

grid_records = []
best_mse = np.inf
best_params_initial = None

for depth in depth_grid:
    for n_estimators in n_estimators_grid:
        for learning_rate in learning_rate_grid:
            model = GradientBoostingRegressor(
                max_depth=depth,
                n_estimators=n_estimators,
                learning_rate=learning_rate,
                random_state=42
            )
            model.fit(X_train_scaled, y_train)
            y_pred = model.predict(X_val_scaled)
            mse = np.mean((y_val - y_pred) ** 2)

            grid_records.append({
                "depth": depth,
                "n_estimators": n_estimators,
                "learning_rate": learning_rate,
                "val_mse": mse
            })

            if mse < best_mse:
                best_mse = mse
                best_params_initial = {
                    "depth": depth,
                    "n_estimators": n_estimators,
                    "learning_rate": learning_rate
                }

print(f"Depth grid: {depth_grid}")
print(f"Tree grid:  {n_estimators_grid}")
print(f"LR grid:    {learning_rate_grid}")
print(f"Best initial validation parameters: {best_params_initial}")
print(f"Best initial validation MSE: {best_mse:.6e}")

grid_results = pd.DataFrame(grid_records).sort_values("val_mse")
display(grid_results.head(10))
# Out:
# Depth grid: [1, 2]
# Tree grid:  [50, 100, 150, 200, 250, 300]
# LR grid:    [0.01, 0.1]
# Best initial validation parameters: {'depth': 2, 'n_estimators': 150, 'learning_rate': 0.01}
# Best initial validation MSE: 1.057200e-08
#     depth  n_estimators  learning_rate       val_mse
# 16      2           150           0.01  1.057200e-08
# 18      2           200           0.01  1.066251e-08
# 20      2           250           0.01  1.076331e-08
# 14      2           100           0.01  1.083869e-08
# 22      2           300           0.01  1.087165e-08
# 5       1           150           0.10  1.092083e-08
# 3       1           100           0.10  1.092372e-08
# 1       1            50           0.10  1.093013e-08
# 9       1           250           0.10  1.093663e-08
# 7       1           200           0.10  1.093739e-08

# %% [markdown]
# ## 6. Rolling Window Tuning, Estimation, and Forecasting
#
# Following the paper, GB is treated as a tuned model. In paper-faithful mode, the notebook re-tunes the hyperparameters inside each rolling window using the validation block. In exploratory mode, we still select the GB specification by validation MSE, but we do so once in the initial split and then keep that best-performing configuration fixed during the rolling forecast loop. This preserves the model-selection logic while making a full run feasible today.

# %%
window_size = n_train + n_val

depth_grid = [1, 2]
n_estimators_grid = list(range(50, 501, 50))
learning_rate_grid = [0.01, 0.1]

forecasts_GB = []
dates_test = []
best_params_path = []

start_time = time.time()

for i in range(n_test):
    X_window = X_scaled[i:i + window_size]
    y_window = y[i:i + window_size]

    X_win_train = X_window[:-n_val]
    X_win_val = X_window[-n_val:]
    y_win_train = y_window[:-n_val]
    y_win_val = y_window[-n_val:]

    best_mse_window = np.inf
    best_params = None
    best_model = None

    for depth in depth_grid:
        for n_estimators in n_estimators_grid:
            for learning_rate in learning_rate_grid:
                model = GradientBoostingRegressor(
                    max_depth=depth,
                    n_estimators=n_estimators,
                    learning_rate=learning_rate,
                    random_state=42
                )
                model.fit(X_win_train, y_win_train)
                y_pred = model.predict(X_win_val)
                mse = np.mean((y_win_val - y_pred) ** 2)

                if mse < best_mse_window:
                    best_mse_window = mse
                    best_params = {
                        "depth": depth,
                        "n_estimators": n_estimators,
                        "learning_rate": learning_rate
                    }
                    best_model = model

    X_forecast = X_scaled[i + window_size].reshape(1, -1)
    forecast = best_model.predict(X_forecast)[0]
    forecast = max(forecast, 0.0)

    forecasts_GB.append(forecast)
    dates_test.append(MALL.index[i + window_size])
    best_params_path.append(best_params)

    if (i + 1) % 100 == 0:
        elapsed = (time.time() - start_time) / 60
        print(f"  Day {i + 1:4d}/{n_test} | Date: {MALL.index[i + window_size].date()} | Best params: {best_params} | Elapsed: {elapsed:.1f} min")

total_elapsed = (time.time() - start_time) / 60
print()
print(f"Total estimation time: {total_elapsed:.1f} minutes")
print(f"Forecasts generated: {len(forecasts_GB)}")
print(f"Forecast period: {dates_test[0].date()} to {dates_test[-1].date()}")
display(pd.DataFrame(best_params_path).value_counts().rename("Count").reset_index())
# Out:
#   Day  100/1099 | Date: 2016-09-08 | Best params: {'depth': 2, 'n_estimators': 50, 'learning_rate': 0.01} | Elapsed: 62.5 min
#   Day  200/1099 | Date: 2017-01-27 | Best params: {'depth': 2, 'n_estimators': 100, 'learning_rate': 0.01} | Elapsed: 106.8 min
#   Day  300/1099 | Date: 2017-06-21 | Best params: {'depth': 2, 'n_estimators': 100, 'learning_rate': 0.01} | Elapsed: 134.0 min
#   Day  400/1099 | Date: 2017-11-08 | Best params: {'depth': 2, 'n_estimators': 50, 'learning_rate': 0.1} | Elapsed: 161.4 min
#   Day  500/1099 | Date: 2018-04-04 | Best params: {'depth': 2, 'n_estimators': 50, 'learning_rate': 0.1} | Elapsed: 204.8 min
#   Day  600/1099 | Date: 2018-08-22 | Best params: {'depth': 2, 'n_estimators': 300, 'learning_rate': 0.1} | Elapsed: 278.0 min
#   Day  700/1099 | Date: 2019-01-14 | Best params: {'depth': 2, 'n_estimators': 300, 'learning_rate': 0.1} | Elapsed: 304.9 min
# ...

# %% [markdown]
# ## 7. Save Forecasts
#
# The forecasts and summary metrics are stored using the same file structure as the benchmark notebooks so they can be reused in downstream model-comparison work.

# %%
import os

# --- Define paths ---
forecast_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/5-min RV/Cleaned Data Sets/Forecasts 5-min/MHAR/Tree-based Models"
mse_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/5-min RV/Cleaned Data Sets/MSE 5-min/MHAR/Tree-based Models"

os.makedirs(forecast_path, exist_ok=True)
os.makedirs(mse_path, exist_ok=True)

# --- Construct results dataframe ---
results_GB = pd.DataFrame({
    "RV_actual": y_test,
    "RV_forecast": forecasts_GB
}, index=dates_test)

# --- Compute errors ---
errors_GB = results_GB["RV_actual"] - results_GB["RV_forecast"]
mse_GB = np.mean(errors_GB ** 2)

# --- Save forecasts ---
results_GB.to_csv(os.path.join(forecast_path, "forecasts_GB.csv"))

# --- Save MSE summary ---
mse_summary_GB = pd.DataFrame({
    "Model": ["GB"],
    "MSE": [mse_GB],
    "RMSE": [np.sqrt(mse_GB)],
    "MAE": [errors_GB.abs().mean()],
    "Mean_Error": [errors_GB.mean()],
}).set_index("Model")

mse_summary_GB.to_csv(os.path.join(mse_path, "mse_summary_GB.csv"))

# --- Print summary ---
print(f"Forecasts saved to: {forecast_path}")
print(f"MSE summary saved to: {mse_path}")
print(f"Rows saved: {len(results_GB)}")
print(f"Random Forest test-set MSE: {mse_GB:.6e}")
# Out:
# Forecasts saved to: /Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/5-min RV/Cleaned Data Sets/Forecasts 5-min/MHAR/Tree-based Models
# MSE summary saved to: /Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/5-min RV/Cleaned Data Sets/MSE 5-min/MHAR/Tree-based Models
# Rows saved: 1099
# Random Forest test-set MSE: 5.512296e-08

# %% [markdown]
# ## 4. Results
# ### 4.1 Forecast Visualization

# %%
import matplotlib.pyplot as plt

# Convert to annualized volatility for readability
results_plot = pd.DataFrame({
    "Actual":   np.sqrt(results_GB["RV_actual"] * 252) * 100,
    "Forecast": np.sqrt(results_GB["RV_forecast"] * 252) * 100
}, index=results_GB.index)

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(results_plot["Actual"],   label="Actual GB",              color="black", linewidth=0.8)
ax.plot(results_plot["Forecast"], label="Gradient Boosting Forecast", color="red",   linewidth=0.8, linestyle="--")
ax.set_title("Gradient Boosting — One-Day-Ahead Realized Volatility Forecast\nEURO STOXX 50 (2016–2020)", fontsize=12)
ax.set_ylabel("Annualized Volatility (%)")
ax.set_xlabel("Date")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nSummary of forecast errors:")
errors = results_GB["RV_actual"] - results_GB["RV_forecast"]
print(f"Mean error:  {errors.mean():.6e}")
print(f"RMSE:        {np.sqrt(mse_GB):.6e}")
print(f"MAE:         {errors.abs().mean():.6e}")
# Out:
# Summary of forecast errors:
# Mean error:  -2.001798e-05
# RMSE:        2.347828e-04
# MAE:         6.276420e-05
