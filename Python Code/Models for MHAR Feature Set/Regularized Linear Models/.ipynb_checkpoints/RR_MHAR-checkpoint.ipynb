# %% [markdown]
# # Ridge Regression (RR) on MHAR Feature Set

# %% [markdown]
# **Purpose:** This notebook implements the Ridge Regression (RR) model of Hoerl and Kennard (1970) on the MHAR feature set for the EURO STOXX 50 index, following the regularized-linear-model approach in Christensen, Siggaard, and Veliyev (2023). Ridge augments the HAR-style regression framework with an L2 penalty that shrinks the coefficients toward zero without setting them exactly equal to zero. This is useful when the predictors are persistent and correlated, as is often the case for realized-volatility measures. As in the reference paper, we standardize the inputs, tune the regularization strength in the validation sample, and then evaluate the model in a one-step-ahead rolling-window exercise that is directly comparable with HAR, LASSO, and Elastic Net.

# %% [markdown]
# ## 1. Imports

# %%
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge

# %% [markdown]
# ## 2. Data Loading
#
# We use the same `MALL.csv` data source as in the HAR benchmarks and the new LASSO and Elastic Net notebooks so that the results are directly comparable across specifications.

# %%
# Load MALL dataset
MALL = pd.read_csv("/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/Cleaned Data/MALL.csv")
MALL["Date"] = pd.to_datetime(MALL["Date"])
MALL = MALL.set_index("Date")

print(f"Sample period: {MALL.index[0].date()} to {MALL.index[-1].date()}")
print(f"Number of observations: {len(MALL)}")
display(MALL[["RVD", "RVW", "RVM", "RV_target"]].head())
# Out:
# Sample period: 1999-01-05 to 2020-08-06
# Number of observations: 5489
#                  RVD       RVW       RVM  RV_target
# Date
# 1999-01-05  0.000078  0.000093  0.000129   0.000058
# 1999-01-06  0.000058  0.000092  0.000123   0.000139
# 1999-01-07  0.000139  0.000102  0.000121   0.000108
# 1999-01-08  0.000108  0.000106  0.000112   0.000166
# 1999-01-11  0.000166  0.000110  0.000110   0.000115

# %% [markdown]
# ## 3. Data Split
#
# To match the rest of the thesis benchmark sequence, we split the data into 70% training observations, 10% validation observations, and 20% test observations. The validation set is reserved for tuning the ridge penalty, while the test set is used only for the final out-of-sample evaluation.

# %%
# Train / Validation / Test split (70 / 10 / 20)
n = len(MALL)
n_train = int(0.70 * n)
n_val = int(0.10 * n)
n_test = n - n_train - n_val

print(f"Training observations:   {n_train}")
print(f"Validation observations: {n_val}")
print(f"Test observations:       {n_test}")

print(f"Training period:   {MALL.index[0].date()} to {MALL.index[n_train - 1].date()}")
print(f"Validation period: {MALL.index[n_train].date()} to {MALL.index[n_train + n_val - 1].date()}")
print(f"Test period:       {MALL.index[n_train + n_val].date()} to {MALL.index[-1].date()}")
# Out:
# Training observations:   3842
# Validation observations: 548
# Test observations:       1099
# Training period:   1999-01-05 to 2014-02-26
# Validation period: 2014-02-27 to 2016-04-20
# Test period:       2016-04-21 to 2020-08-06

# %% [markdown]
# ## 4. Feature Set Construction and Standardization
#
# The reference paper stresses that regularized regressions should be estimated on standardized predictors. We therefore scale the MHAR regressors using moments from the training sample only and keep the target variable in levels so that the forecast accuracy remains directly comparable with HAR and its extensions.

# %%
# Define target and MHAR feature set
y = MALL["RV_target"].values
X_MHAR = MALL[["RVD", "RVW", "RVM"]].values

# Split into train, validation and test sets
X_train = X_MHAR[:n_train]
X_val = X_MHAR[n_train:n_train + n_val]
X_test = X_MHAR[n_train + n_val:]

y_train = y[:n_train]
y_val = y[n_train:n_train + n_val]
y_test = y[n_train + n_val:]

# Compute standardization parameters from training set only
X_mean = X_train.mean(axis=0)
X_std = X_train.std(axis=0)
X_std = np.where(X_std == 0, 1.0, X_std)

# Scale full dataset using training-set parameters
X_scaled = (X_MHAR - X_mean) / X_std

X_train_scaled = X_scaled[:n_train]
X_val_scaled = X_scaled[n_train:n_train + n_val]
X_test_scaled = X_scaled[n_train + n_val:]

print("Feature set: RVD, RVW, RVM")
print(f"\nFull dataset:   X={X_scaled.shape}, y={y.shape}")
print(f"Training set:   X={X_train_scaled.shape}, y={y_train.shape}")
print(f"Validation set: X={X_val_scaled.shape}, y={y_val.shape}")
print(f"Test set:       X={X_test_scaled.shape}, y={y_test.shape}")
print("\nStandardization check on training sample:")
print(f"  Means: {X_train_scaled.mean(axis=0).round(6)}")
print(f"  Std:   {X_train_scaled.std(axis=0).round(6)}")
# Out:
# Feature set: RVD, RVW, RVM
#
# Full dataset:   X=(5489, 3), y=(5489,)
# Training set:   X=(3842, 3), y=(3842,)
# Validation set: X=(548, 3), y=(548,)
# Test set:       X=(1099, 3), y=(1099,)
#
# Standardization check on training sample:
#   Means: [-0.  0. -0.]
#   Std:   [1. 1. 1.]

# %% [markdown]
# ## 5. Ridge Model Specification and Hyperparameter Tuning
#
# Following the paper, we tune the ridge penalty over a broad logarithmic grid so that both weak and strong shrinkage remain feasible candidates. The hyperparameter is chosen by the validation-set MSE, and we verify that the selected value lies away from the boundary of the search interval.

# %%
# Define ridge penalty grid following the paper
alpha_grid = np.logspace(-5, 2, 1000)

val_mse = []
coef_norms = []

for alpha in alpha_grid:
    model = Ridge(alpha=alpha, fit_intercept=True)
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_val_scaled)
    val_mse.append(np.mean((y_val - y_pred) ** 2))
    coef_norms.append(np.linalg.norm(model.coef_, ord=2))

best_idx = int(np.argmin(val_mse))
optimal_alpha = alpha_grid[best_idx]
optimal_val_mse = val_mse[best_idx]

print(f"Grid size: {len(alpha_grid)}")
print(f"Alpha range: {alpha_grid[0]:.2e} to {alpha_grid[-1]:.2e}")
print(f"Optimal alpha: {optimal_alpha:.6e}")
print(f"Validation MSE: {optimal_val_mse:.6e}")
print(f"Position in grid: {best_idx} / {len(alpha_grid)}")
if best_idx == 0:
    print("Warning: optimum is at the lower boundary.")
elif best_idx == len(alpha_grid) - 1:
    print("Warning: optimum is at the upper boundary.")
else:
    print("Optimal alpha is an interior point of the grid.")

fig, ax1 = plt.subplots(figsize=(10, 4))
ax1.semilogx(alpha_grid, val_mse, color="black", linewidth=0.8)
ax1.axvline(optimal_alpha, color="red", linestyle="--", linewidth=1.0, label=f"Optimal alpha = {optimal_alpha:.2e}")
ax1.set_xlabel("Alpha (log scale)")
ax1.set_ylabel("Validation MSE")
ax1.set_title("Ridge Regression — Validation MSE vs Regularization Strength\nMHAR Feature Set", fontsize=11)
ax1.grid(True, alpha=0.3)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.semilogx(alpha_grid, coef_norms, color="steelblue", linewidth=0.8, alpha=0.8)
ax2.set_ylabel("L2 norm of coefficient vector")
plt.tight_layout()
plt.show()
# Out:
# Grid size: 1000
# Alpha range: 1.00e-05 to 1.00e+02
# Optimal alpha: 1.000000e+02
# Validation MSE: 1.720136e-08
# Position in grid: 999 / 1000
# ...

# %% [markdown]
# ## 6. Rolling Window Estimation and Forecasting
#
# We now carry the selected ridge penalty into the rolling one-step-ahead forecast exercise. The rolling window length equals the initial training plus validation sample, matching the setup used in HAR, LASSO, and Elastic Net.

# %%
fixed_alpha = optimal_alpha
window_size = n_train + n_val

print(f"Fixed alpha from validation tuning: {fixed_alpha:.6e}")
print(f"Rolling window length: {window_size}")

forecasts_RR = []
dates_test = []
coef_norm_path = []

start_time = time.time()

for i in range(n_test):
    X_window = X_scaled[i:i + window_size]
    y_window = y[i:i + window_size]

    model_final = Ridge(alpha=fixed_alpha, fit_intercept=True)
    model_final.fit(X_window, y_window)

    X_forecast = X_scaled[i + window_size].reshape(1, -1)
    forecast = model_final.predict(X_forecast)[0]
    forecast = max(forecast, y_window.min())

    forecasts_RR.append(forecast)
    dates_test.append(MALL.index[i + window_size])
    coef_norm_path.append(np.linalg.norm(model_final.coef_, ord=2))

    if (i + 1) % 100 == 0:
        elapsed = (time.time() - start_time) / 60
        print(f"  Day {i + 1:4d}/{n_test} | Date: {MALL.index[i + window_size].date()} | Elapsed: {elapsed:.1f} min")

total_elapsed = (time.time() - start_time) / 60
print(f"\nTotal estimation time: {total_elapsed:.1f} minutes")
print(f"Forecasts generated: {len(forecasts_RR)}")
print(f"Forecast period: {dates_test[0].date()} to {dates_test[-1].date()}")
print(f"Average coefficient L2 norm: {np.mean(coef_norm_path):.6f}")
# Out:
# Fixed alpha from validation tuning: 1.000000e+02
# Rolling window length: 4390
#   Day  100/1099 | Date: 2016-09-08 | Elapsed: 0.0 min
#   Day  200/1099 | Date: 2017-01-27 | Elapsed: 0.0 min
#   Day  300/1099 | Date: 2017-06-21 | Elapsed: 0.0 min
#   Day  400/1099 | Date: 2017-11-08 | Elapsed: 0.0 min
#   Day  500/1099 | Date: 2018-04-04 | Elapsed: 0.0 min
#   Day  600/1099 | Date: 2018-08-22 | Elapsed: 0.0 min
#   Day  700/1099 | Date: 2019-01-14 | Elapsed: 0.0 min
#   Day  800/1099 | Date: 2019-06-06 | Elapsed: 0.0 min
#   Day  900/1099 | Date: 2019-10-24 | Elapsed: 0.0 min
#   Day 1000/1099 | Date: 2020-03-17 | Elapsed: 0.0 min
#
# Total estimation time: 0.0 minutes
# Forecasts generated: 1099
# Forecast period: 2016-04-21 to 2020-08-06
# Average coefficient L2 norm: 0.000125

# %% [markdown]
# ## 7. Save Forecasts
#
# We save the forecast path and the standard accuracy metrics using the same output structure as the other benchmark notebooks so the results can be reused downstream without additional reshaping.

# %%
forecast_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/Cleaned Data/Forcasts/MHAR"
os.makedirs(forecast_path, exist_ok=True)

test_dates = MALL.index[n_train + n_val:]
results_RR = pd.DataFrame({
    "RV_actual": y_test,
    "RV_forecast": forecasts_RR
}, index=test_dates)

errors_RR = results_RR["RV_actual"] - results_RR["RV_forecast"]
mse_RR = np.mean(errors_RR ** 2)

results_RR.to_csv(os.path.join(forecast_path, "forecasts_RR.csv"))

mse_summary_RR = pd.DataFrame({
    "Model": ["RR"],
    "MSE": [mse_RR],
    "RMSE": [np.sqrt(mse_RR)],
    "MAE": [errors_RR.abs().mean()],
    "Mean_Error": [errors_RR.mean()],
}).set_index("Model")

mse_summary_RR.to_csv(os.path.join(forecast_path, "mse_summary_RR.csv"))

print(f"Forecasts saved to: {forecast_path}")
print(f"Rows saved: {len(results_RR)}")
print(f"Ridge test-set MSE: {mse_RR:.6e}")
# Out:
# Forecasts saved to: /Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/Cleaned Data/Forcasts/MHAR
# Rows saved: 1099
# Ridge test-set MSE: 2.237301e-08

# %% [markdown]
# ## 8. Out-of-Sample Performance Evaluation
#
# We first benchmark ridge against the HAR model on the common test period and report the same level-scale performance measures used throughout the thesis notebooks.

# %%
forecast_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/Cleaned Data/Forcasts/MHAR"
results_HAR = pd.read_csv(
    os.path.join(forecast_path, "forecasts_HAR.csv"),
    index_col=0,
    parse_dates=True
)

mse_HAR = np.mean((results_HAR["RV_actual"] - results_HAR["RV_forecast"]) ** 2)
errors_HAR = results_HAR["RV_actual"] - results_HAR["RV_forecast"]
rel_mse_RR = mse_RR / mse_HAR

print(f"Out-of-sample performance ({test_dates[0].date()} to {test_dates[-1].date()}):")
print(f"\n{'Model':<10} {'MSE':>12} {'RMSE':>12} {'MAE':>12} {'Mean Error':>12} {'Rel. MSE':>10}")
print("-" * 70)
print(f"{'HAR':<10} {mse_HAR:>12.6e} {np.sqrt(mse_HAR):>12.6e} {errors_HAR.abs().mean():>12.6e} {errors_HAR.mean():>12.6e} {1.0:>10.4f}")
print(f"{'RR':<10} {mse_RR:>12.6e} {np.sqrt(mse_RR):>12.6e} {errors_RR.abs().mean():>12.6e} {errors_RR.mean():>12.6e} {rel_mse_RR:>10.4f}")
print("-" * 70)
print(f"\nRR vs HAR: {'outperforms' if rel_mse_RR < 1 else 'underperforms'} by {abs(1 - rel_mse_RR) * 100:.2f}%")
# Out:
# Out-of-sample performance (2016-04-21 to 2020-08-06):
#
# Model               MSE         RMSE          MAE   Mean Error   Rel. MSE
# ----------------------------------------------------------------------
# HAR        2.221336e-08 1.490415e-04 5.592501e-05 -4.057863e-06     1.0000
# RR         2.237301e-08 1.495761e-04 5.621280e-05 -4.442572e-06     1.0072
# ----------------------------------------------------------------------
#
# RR vs HAR: underperforms by 0.72%

# %% [markdown]
# ## 9. Forecast Visualization
#
# As in the other benchmark notebooks, we convert realized variance into annualized volatility before plotting the actual and forecasted series. This keeps the graph readable and comparable across all specifications.

# %%
results_plot_RR = pd.DataFrame({
    "Actual": np.sqrt(results_RR["RV_actual"] * 252) * 100,
    "Forecast": np.sqrt(results_RR["RV_forecast"] * 252) * 100
}, index=results_RR.index)

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(results_plot_RR["Actual"], label="Actual RV", color="black", linewidth=0.8)
ax.plot(results_plot_RR["Forecast"], label="Ridge Forecast", color="red", linewidth=0.8, linestyle="--")
ax.set_title("Ridge Regression — One-Day-Ahead Realized Volatility Forecast\nEURO STOXX 50 (2016–2020)", fontsize=12)
ax.set_ylabel("Annualized Volatility (%)")
ax.set_xlabel("Date")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nSummary of forecast errors:")
print(f"Mean error:  {errors_RR.mean():.6e}")
print(f"RMSE:        {np.sqrt(mse_RR):.6e}")
print(f"MAE:         {errors_RR.abs().mean():.6e}")
print(f"Average coefficient L2 norm in rolling estimation: {np.mean(coef_norm_path):.6f}")
# Out:
# Summary of forecast errors:
# Mean error:  -4.442572e-06
# RMSE:        1.495761e-04
# MAE:         5.621280e-05
# Average coefficient L2 norm in rolling estimation: 0.000125

# %% [markdown]
# ## 10. Comparison with HAR, LASSO, and Elastic Net
#
# To close the notebook, we place ridge next to HAR, LASSO, and Elastic Net using the saved test-set summaries. The key quantity is the relative MSE: values above one imply a model underperforms HAR, while values below one imply an improvement over HAR.

# %%
forecast_path = "/Users/tobiasbergdahlpersson/Documents/SSE/MSc Thesis/Cleaned Data/Forcasts/MHAR"
summary_frames = []
for model in ["HAR", "LA", "EN", "RR"]:
    df = pd.read_csv(os.path.join(forecast_path, f"mse_summary_{model}.csv"))
    summary_frames.append(df)

comparison = pd.concat(summary_frames, ignore_index=True).set_index("Model")
comparison["Relative_MSE_vs_HAR"] = comparison["MSE"] / comparison.loc["HAR", "MSE"]
comparison["HAR_relative_to_model"] = comparison.loc["HAR", "MSE"] / comparison["MSE"]
comparison = comparison[["MSE", "RMSE", "MAE", "Mean_Error", "Relative_MSE_vs_HAR", "HAR_relative_to_model"]]

print("Test-set MSE comparison (2016-2020):")
display(comparison)

print()
print("Relative MSE interpretation:")
print(f"  LA relative MSE vs HAR: {comparison.loc['LA', 'Relative_MSE_vs_HAR']:.4f}")
print(f"  EN relative MSE vs HAR: {comparison.loc['EN', 'Relative_MSE_vs_HAR']:.4f}")
print(f"  RR relative MSE vs HAR: {comparison.loc['RR', 'Relative_MSE_vs_HAR']:.4f}")

print()
print("HAR MSE relative to each regularized model:")
print(f"  HAR / LA: {comparison.loc['HAR', 'MSE'] / comparison.loc['LA', 'MSE']:.4f}")
print(f"  HAR / EN: {comparison.loc['HAR', 'MSE'] / comparison.loc['EN', 'MSE']:.4f}")
print(f"  HAR / RR: {comparison.loc['HAR', 'MSE'] / comparison.loc['RR', 'MSE']:.4f}")
# Out:
# Test-set MSE comparison (2016-2020):
#                 MSE      RMSE       MAE  Mean_Error  Relative_MSE_vs_HAR  \
# Model
# HAR    2.221336e-08  0.000149  0.000056   -0.000004             1.000000
# LA     2.379929e-08  0.000154  0.000064   -0.000012             1.071396
# EN     2.381588e-08  0.000154  0.000064   -0.000012             1.072143
# RR     2.237301e-08  0.000150  0.000056   -0.000004             1.007187
#
#        HAR_relative_to_model
# Model
# HAR                 1.000000
# LA                  0.933362
# EN                  0.932712
# RR                  0.992864
# Relative MSE interpretation:
#   LA relative MSE vs HAR: 1.0714
#   EN relative MSE vs HAR: 1.0721
#   RR relative MSE vs HAR: 1.0072
#
# HAR MSE relative to each regularized model:
#   HAR / LA: 0.9334
#   HAR / EN: 0.9327
#   HAR / RR: 0.9929
